# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('scopus_master_with_references_formatted_2_230614_month_year_aff_names.xlsx')

# %%
df
# Out:
#         ID                                   STUDY TITLE/NAME  \
# 0        1  Rapid Serological Tests Have a Role in Asympto...
# 1        2  Evaluation of a Rapid Diagnostic Assay for Det...
# 2        3  Clinical Course and Molecular Viral Shedding f...
# 3        4  Clinical Impact, Costs, and Cost-Effectiveness...
# 4        5  DETECT study: Wearable Fitness Devices Can Imp...
# ...    ...                                                ...
# 4794  3833  A prospective clinical evaluation of the diagn...
# 4795  3834  Evaluation of the QIAstat-Dx Respiratory SARS-...
# 4796  3834  Evaluation of the QIAstat-Dx Respiratory SARS-...
# 4797  3835  Three SARS-CoV-2 PCR-negative cases of COVID-1...
# 4798  3835  Three SARS-CoV-2 PCR-negative cases of COVID-1...
#
#                                       STUDY DESCRIPTION  \
# 0     Viva-Diag Rapid anti-SARS-CoV-2 IgM-positive v...
# 1     COVID-19 Ag Respi-Strip was compared with PCR ...
# ...

# %%
df = df.drop_duplicates(subset=["dc:title_y"], keep='last')

# %%
df
# Out:
#         ID                                   STUDY TITLE/NAME  \
# 0        1  Rapid Serological Tests Have a Role in Asympto...
# 2        3  Clinical Course and Molecular Viral Shedding f...
# 3        4  Clinical Impact, Costs, and Cost-Effectiveness...
# 5        5  DETECT study: Wearable Fitness Devices Can Imp...
# 6        6  Electric Field-driven Microfluidics for Rapid ...
# ...    ...                                                ...
# 4791  3831  The Panbio COVID-19 Ag Rapid Test: Which Perfo...
# 4792  3832  Duplex Reverse Transcription Multienzyme Isoth...
# 4794  3833  A prospective clinical evaluation of the diagn...
# 4796  3834  Evaluation of the QIAstat-Dx Respiratory SARS-...
# 4798  3835  Three SARS-CoV-2 PCR-negative cases of COVID-1...
#
#                                       STUDY DESCRIPTION  \
# 0     Viva-Diag Rapid anti-SARS-CoV-2 IgM-positive v...
# 2     PCR was used to determine Cycle threshold (Ct)...
# ...

# %%
df.to_excel('scopus_master_ref_formatted2_aff_names_dctitle_y_dup_removed_230614.xlsx',index=False)
