# %%
import pandas as pd
import numpy as np
import requests
import json
import urllib.parse

# %%
df_freq = pd.read_excel("eid_affid_frequency.xlsx")

# %%
df_freq = df_freq[["affid", "frequency"]]

# %%
df_freq
# Out:
#           affid  frequency
# 0      60020183          1
# 1      60012957         15
# 2      60026748          4
# 3      60025615          3
# 4      60023859          1
# ...         ...        ...
# 6965  127854475          1
# 6966   60117061          1
# 6967  112744495          1
# 6968  101341967          1
# 6969  112870360          1
#
# [6970 rows x 2 columns]

# %%
df_aff = pd.read_excel("aff_cols_affsearch_query_aff_indi_cols_success_with_doccount_parentid_final.xlsx")

# %%
df_aff
# Out:
#                      eid                                              title  \
# 0     2-s2.0-85099799917  Rapid Serological Tests Have a Role in Asympto...
# 1     2-s2.0-85099799917  Rapid Serological Tests Have a Role in Asympto...
# 2     2-s2.0-85089978670  Clinical Course and Molecular Viral Shedding f...
# 3     2-s2.0-85089978670  Clinical Course and Molecular Viral Shedding f...
# 4     2-s2.0-85089978670  Clinical Course and Molecular Viral Shedding f...
# ...                  ...                                                ...
# 6965  2-s2.0-85106069033  Comparing Nasopharyngeal Swab and Early Mornin...
# 6966  2-s2.0-85122773272  Longitudinal Study of the Signal Strength in t...
# 6967  2-s2.0-85125696300  A prospective clinical evaluation of the diagn...
# 6968  2-s2.0-85125696300  A prospective clinical evaluation of the diagn...
# 6969  2-s2.0-85128229965  Three SARS-CoV-2 PCR-negative cases of COVID-1...
#
# ...

# %%
df_new = pd.merge(df_aff, df_freq, on="affid")

# %%
df_new
# Out:
#                      eid                                              title  \
# 0     2-s2.0-85099799917  Rapid Serological Tests Have a Role in Asympto...
# 1     2-s2.0-85099799917  Rapid Serological Tests Have a Role in Asympto...
# 2     2-s2.0-85089978670  Clinical Course and Molecular Viral Shedding f...
# 3     2-s2.0-85089978670  Clinical Course and Molecular Viral Shedding f...
# 4     2-s2.0-85089978670  Clinical Course and Molecular Viral Shedding f...
# ...                  ...                                                ...
# 6965  2-s2.0-85106069033  Comparing Nasopharyngeal Swab and Early Mornin...
# 6966  2-s2.0-85122773272  Longitudinal Study of the Signal Strength in t...
# 6967  2-s2.0-85125696300  A prospective clinical evaluation of the diagn...
# 6968  2-s2.0-85125696300  A prospective clinical evaluation of the diagn...
# 6969  2-s2.0-85128229965  Three SARS-CoV-2 PCR-negative cases of COVID-1...
#
# ...

# %%
df_new.to_excel("affilitaion_cols_complete_with_frequency.xlsx", index= False)
